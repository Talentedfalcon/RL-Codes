# %% [markdown]
# ## Cart Pole

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env=gym.make('CartPole-v1')

model=PPO(policy="MlpPolicy",env=env,verbose=1)

rewards=[]

for episode in range(100):
    model.learn(total_timesteps=1000)
    mean_reward,_=evaluate_policy(model,env,n_eval_episodes=5)
    rewards.append(mean_reward)
    print(f"Episode:{episode+1}\tMean Reward:{mean_reward}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /mnt/c/Users/Falcon/Desktop/RL/RL_env/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 20.4     |
# | time/              |          |
# |    fps             | 268      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# /mnt/c/Users/Falcon/Desktop/RL/RL_env/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Episode:1	Mean Reward:75.6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.4     |
# |    ep_rew_mean     | 30.4     |
# | time/              |          |
# |    fps             | 300      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:2	Mean Reward:110.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.4     |
# |    ep_rew_mean     | 46.4     |
# | time/              |          |
# |    fps             | 276      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:3	Mean Reward:177.4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.7     |
# |    ep_rew_mean     | 61.7     |
# | time/              |          |
# |    fps             | 280      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:4	Mean Reward:323.4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:5	Mean Reward:347.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    fps             | 287      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:6	Mean Reward:469.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 216      |
# | time/              |          |
# |    fps             | 271      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:7	Mean Reward:423.4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    fps             | 272      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:8	Mean Reward:453.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 280      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    fps             | 275      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:9	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 394      |
# |    ep_rew_mean     | 394      |
# | time/              |          |
# |    fps             | 293      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:10	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    fps             | 273      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:11	Mean Reward:498.6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 498      |
# |    ep_rew_mean     | 498      |
# | time/              |          |
# |    fps             | 281      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:12	Mean Reward:400.2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 404      |
# |    ep_rew_mean     | 404      |
# | time/              |          |
# |    fps             | 271      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:13	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:14	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 288      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:15	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 268      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:16	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 273      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:17	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 276      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:18	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 284      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:19	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:20	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 269      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:21	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 279      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:22	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 265      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:23	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 269      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:24	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 266      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:25	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 274      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:26	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 296      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:27	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:28	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:29	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:30	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 293      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:31	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 277      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:32	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 290      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:33	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 286      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:34	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:35	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:36	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 289      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:37	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 286      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:38	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 276      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:39	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 296      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:40	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:41	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 277      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:42	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 290      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:43	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 290      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:44	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:45	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 279      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:46	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 308      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:47	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 295      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:48	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 292      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:49	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 284      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:50	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 274      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:51	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 279      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:52	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 300      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:53	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:54	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 301      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:55	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 297      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:56	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 275      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:57	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 274      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:58	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:59	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:60	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 294      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:61	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 301      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:62	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 287      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:63	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 300      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:64	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 276      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:65	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 290      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:66	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:67	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:68	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 296      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:69	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:70	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:71	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 273      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:72	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 294      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:73	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 289      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:74	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 290      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:75	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 292      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:76	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:77	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 294      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:78	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 282      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:79	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 289      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:80	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 290      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:81	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 287      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:82	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:83	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 281      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:84	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 289      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:85	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 286      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:86	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 284      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:87	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 289      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:88	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 292      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:89	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 292      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:90	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 281      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:91	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 292      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:92	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 280      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:93	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:94	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 302      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:95	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 287      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:96	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 280      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:97	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 284      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:98	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 277      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:99	Mean Reward:500.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    fps             | 286      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:100	Mean Reward:500.0

# %%
model.save("ppo_cartpole")

# %%
plt.plot(rewards)
plt.title("Cumulative Reward vs Episode")
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.grid(True)
plt.show()

# %%
model=model.load('ppo_cartpole.zip')

env = gym.make("CartPole-v1",render_mode="human")

obs,info = env.reset()
done = False

obs,info = env.reset()
for _ in range(500):
    action, _ = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    env.render()

    if done:
        obs,info = env.reset()

env.close()
# Out:
# /mnt/c/Users/Falcon/Desktop/RL/RL_env/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %% [markdown]
# ## Lunar Lander

# %%
env=gym.make('LunarLander-v3')

model=PPO(policy="MlpPolicy",env=env,verbose=1)

rewards=[]

for episode in range(100):
    model.learn(total_timesteps=1000)
    mean_reward,_=evaluate_policy(model,env,n_eval_episodes=5)
    rewards.append(mean_reward)
    print(f"Episode:{episode+1}\tMean Reward:{mean_reward}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.5     |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    fps             | 247      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# /mnt/c/Users/Falcon/Desktop/RL/RL_env/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Episode:1	Mean Reward:-126.17841402161866
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | -171     |
# | time/              |          |
# |    fps             | 264      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:2	Mean Reward:-147.55705971261486
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.4     |
# |    ep_rew_mean     | -152     |
# | time/              |          |
# |    fps             | 278      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:3	Mean Reward:-185.0002652414143
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88       |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    fps             | 262      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:4	Mean Reward:-171.89922731686383
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.4     |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    fps             | 275      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:5	Mean Reward:94.71525890602464
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.5     |
# |    ep_rew_mean     | -133     |
# | time/              |          |
# |    fps             | 251      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:6	Mean Reward:-63.46058439426124
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.6     |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    fps             | 235      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:7	Mean Reward:-417.51156537067146
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -95.9    |
# | time/              |          |
# |    fps             | 248      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:8	Mean Reward:-319.7977917750133
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | -96.4    |
# | time/              |          |
# |    fps             | 216      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:9	Mean Reward:-767.7900608903728
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -84.1    |
# | time/              |          |
# |    fps             | 217      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:10	Mean Reward:-548.4928559074178
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -89.2    |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:11	Mean Reward:-812.730290985899
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | -67.3    |
# | time/              |          |
# |    fps             | 194      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:12	Mean Reward:-495.83004578379916
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | -167     |
# | time/              |          |
# |    fps             | 223      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:13	Mean Reward:-863.5726767479442
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -204     |
# | time/              |          |
# |    fps             | 230      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:14	Mean Reward:-480.0939221424982
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    fps             | 209      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:15	Mean Reward:-275.9898292951286
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    fps             | 231      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:16	Mean Reward:-679.5314531301032
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 219      |
# |    ep_rew_mean     | -151     |
# | time/              |          |
# |    fps             | 221      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:17	Mean Reward:-648.9647487461101
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    fps             | 218      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:18	Mean Reward:-991.3580779213459
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 256      |
# |    ep_rew_mean     | -132     |
# | time/              |          |
# |    fps             | 232      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:19	Mean Reward:-801.5806783342268
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 401      |
# |    ep_rew_mean     | -18.2    |
# | time/              |          |
# |    fps             | 218      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:20	Mean Reward:-1527.446592220897
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 253      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    fps             | 207      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:21	Mean Reward:-1311.2338575381552
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 371      |
# |    ep_rew_mean     | -134     |
# | time/              |          |
# |    fps             | 228      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:22	Mean Reward:-1808.1819258882665
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 281      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    fps             | 194      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:23	Mean Reward:-1938.902300032042
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 450      |
# |    ep_rew_mean     | -178     |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:24	Mean Reward:-785.3722736453171
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 732      |
# |    ep_rew_mean     | -5.58    |
# | time/              |          |
# |    fps             | 191      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:25	Mean Reward:-1080.289341052668
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 614      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    fps             | 214      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:26	Mean Reward:-798.3203833086766
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 26.5     |
# | time/              |          |
# |    fps             | 227      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:27	Mean Reward:-671.8223500278779
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 568      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    fps             | 218      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:28	Mean Reward:-633.6716401063837
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 744      |
# |    ep_rew_mean     | -142     |
# | time/              |          |
# |    fps             | 204      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:29	Mean Reward:-283.9788968561217
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 466      |
# |    ep_rew_mean     | -22.3    |
# | time/              |          |
# |    fps             | 194      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:30	Mean Reward:-223.418255050882
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -4.89    |
# | time/              |          |
# |    fps             | 214      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:31	Mean Reward:-241.8180772032123
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 582      |
# |    ep_rew_mean     | -37      |
# | time/              |          |
# |    fps             | 209      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:32	Mean Reward:-253.39294046582071
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 890      |
# |    ep_rew_mean     | 46.8     |
# | time/              |          |
# |    fps             | 213      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:33	Mean Reward:-292.4419923188405
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 892      |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    fps             | 215      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:34	Mean Reward:-204.43683566893452
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 996      |
# |    ep_rew_mean     | 34.6     |
# | time/              |          |
# |    fps             | 190      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:35	Mean Reward:-149.38886682651938
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 427      |
# |    ep_rew_mean     | -45      |
# | time/              |          |
# |    fps             | 216      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:36	Mean Reward:-163.43128053048858
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 640      |
# |    ep_rew_mean     | -129     |
# | time/              |          |
# |    fps             | 214      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:37	Mean Reward:-149.84443853619376
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -8.19    |
# | time/              |          |
# |    fps             | 192      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:38	Mean Reward:-76.22260072291537
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 817      |
# |    ep_rew_mean     | -2.5     |
# | time/              |          |
# |    fps             | 191      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:39	Mean Reward:-90.29201489189873
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 676      |
# |    ep_rew_mean     | -56.6    |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:40	Mean Reward:-98.74468092179158
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 19.9     |
# | time/              |          |
# |    fps             | 221      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:41	Mean Reward:-102.34995450479619
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 82.4     |
# | time/              |          |
# |    fps             | 209      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:42	Mean Reward:-106.12950805763975
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 704      |
# |    ep_rew_mean     | -17      |
# | time/              |          |
# |    fps             | 206      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:43	Mean Reward:-120.90849475010472
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 778      |
# |    ep_rew_mean     | -49.7    |
# | time/              |          |
# |    fps             | 221      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:44	Mean Reward:-92.51179665704913
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 53.5     |
# | time/              |          |
# |    fps             | 195      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:45	Mean Reward:-100.4618579541595
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 715      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    fps             | 211      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:46	Mean Reward:-131.77928843298506
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -46.7    |
# | time/              |          |
# |    fps             | 193      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:47	Mean Reward:10.956356300574488
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    fps             | 201      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:48	Mean Reward:4.28500136717048
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 49.4     |
# | time/              |          |
# |    fps             | 197      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:49	Mean Reward:-58.085929828410734
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    fps             | 209      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:50	Mean Reward:-12.504511734119683
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 740      |
# |    ep_rew_mean     | -29.8    |
# | time/              |          |
# |    fps             | 205      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:51	Mean Reward:-62.88368678684346
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 854      |
# |    ep_rew_mean     | 98.4     |
# | time/              |          |
# |    fps             | 195      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:52	Mean Reward:-139.10259779240005
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 441      |
# |    ep_rew_mean     | -66.9    |
# | time/              |          |
# |    fps             | 196      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:53	Mean Reward:-72.94075922927296
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 649      |
# |    ep_rew_mean     | 44.1     |
# | time/              |          |
# |    fps             | 213      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:54	Mean Reward:-77.62985931051298
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 892      |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    fps             | 195      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:55	Mean Reward:-2.585400465206783
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 497      |
# |    ep_rew_mean     | 76.7     |
# | time/              |          |
# |    fps             | 216      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:56	Mean Reward:-76.35324399555684
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | 203      |
# | time/              |          |
# |    fps             | 204      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:57	Mean Reward:6.4008980660422825
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 582      |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    fps             | 201      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:58	Mean Reward:26.59449944156903
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 476      |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    fps             | 214      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:59	Mean Reward:25.594253298907894
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 477      |
# |    ep_rew_mean     | 34.9     |
# | time/              |          |
# |    fps             | 209      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:60	Mean Reward:-31.515781496386627
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 625      |
# |    ep_rew_mean     | 69.1     |
# | time/              |          |
# |    fps             | 197      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:61	Mean Reward:-40.8766526514785
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 655      |
# |    ep_rew_mean     | 79.3     |
# | time/              |          |
# |    fps             | 198      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:62	Mean Reward:-56.81002972201677
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 436      |
# |    ep_rew_mean     | 74.1     |
# | time/              |          |
# |    fps             | 187      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:63	Mean Reward:-47.28015319836682
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 405      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    fps             | 186      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:64	Mean Reward:-114.68845587328542
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 449      |
# |    ep_rew_mean     | -26.2    |
# | time/              |          |
# |    fps             | 177      |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:65	Mean Reward:-142.36776588088833
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 393      |
# |    ep_rew_mean     | 59.6     |
# | time/              |          |
# |    fps             | 210      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:66	Mean Reward:115.23439371227244
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 346      |
# |    ep_rew_mean     | -16.7    |
# | time/              |          |
# |    fps             | 204      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:67	Mean Reward:-74.26550509622321
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 375      |
# |    ep_rew_mean     | 51.9     |
# | time/              |          |
# |    fps             | 184      |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:68	Mean Reward:11.986999853731072
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 373      |
# |    ep_rew_mean     | -9.55    |
# | time/              |          |
# |    fps             | 185      |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:69	Mean Reward:100.90933108426013
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 432      |
# |    ep_rew_mean     | 69.3     |
# | time/              |          |
# |    fps             | 175      |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:70	Mean Reward:-54.7884488506376
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 626      |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    fps             | 211      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:71	Mean Reward:97.93611700931083
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    fps             | 211      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:72	Mean Reward:73.10748492403064
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 421      |
# |    ep_rew_mean     | 44.8     |
# | time/              |          |
# |    fps             | 207      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:73	Mean Reward:-6.500228050514124
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    fps             | 229      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:74	Mean Reward:15.231426539323014
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 482      |
# |    ep_rew_mean     | 55.2     |
# | time/              |          |
# |    fps             | 211      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:75	Mean Reward:100.4984781375284
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 570      |
# |    ep_rew_mean     | -1.75    |
# | time/              |          |
# |    fps             | 209      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:76	Mean Reward:85.79347884385507
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 545      |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    fps             | 216      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:77	Mean Reward:39.91604016373386
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    fps             | 211      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:78	Mean Reward:29.9784971681838
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 408      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    fps             | 199      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:79	Mean Reward:-4.0602043157291
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 615      |
# |    ep_rew_mean     | 26       |
# | time/              |          |
# |    fps             | 224      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:80	Mean Reward:139.06460658238422
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 803      |
# |    ep_rew_mean     | -62.5    |
# | time/              |          |
# |    fps             | 196      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:81	Mean Reward:-26.50362235370968
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 814      |
# |    ep_rew_mean     | 33.7     |
# | time/              |          |
# |    fps             | 239      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:82	Mean Reward:19.780226917075574
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -33.3    |
# | time/              |          |
# |    fps             | 218      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:83	Mean Reward:73.14323285710485
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 595      |
# |    ep_rew_mean     | 18.3     |
# | time/              |          |
# |    fps             | 230      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:84	Mean Reward:36.29004818435799
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 573      |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    fps             | 279      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:85	Mean Reward:22.265201668886345
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 682      |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    fps             | 265      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:86	Mean Reward:-69.27252388398628
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 362      |
# |    ep_rew_mean     | 94.3     |
# | time/              |          |
# |    fps             | 261      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:87	Mean Reward:122.25282363832714
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 377      |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    fps             | 245      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:88	Mean Reward:101.88371862426234
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    fps             | 268      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:89	Mean Reward:29.36450113443005
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    fps             | 249      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:90	Mean Reward:27.714913318098162
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 417      |
# |    ep_rew_mean     | 90.5     |
# | time/              |          |
# |    fps             | 258      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:91	Mean Reward:118.91927079432853
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 483      |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    fps             | 252      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:92	Mean Reward:157.96634233778641
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 431      |
# |    ep_rew_mean     | 10.6     |
# | time/              |          |
# |    fps             | 264      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:93	Mean Reward:50.1216799538897
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 668      |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    fps             | 261      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:94	Mean Reward:85.92753169506389
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 614      |
# |    ep_rew_mean     | 79.8     |
# | time/              |          |
# |    fps             | 251      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:95	Mean Reward:72.73806571095244
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 463      |
# |    ep_rew_mean     | 63.3     |
# | time/              |          |
# |    fps             | 268      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:96	Mean Reward:118.50631767117675
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 802      |
# |    ep_rew_mean     | 85.8     |
# | time/              |          |
# |    fps             | 255      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:97	Mean Reward:84.19848087659264
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 468      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    fps             | 261      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:98	Mean Reward:84.83107322882711
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 487      |
# |    ep_rew_mean     | 78.9     |
# | time/              |          |
# |    fps             | 261      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:99	Mean Reward:158.45444231961778
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 349      |
# |    ep_rew_mean     | 16.5     |
# | time/              |          |
# |    fps             | 264      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode:100	Mean Reward:148.67465254334633

# %%
model.save("ppo_lunarlander")

# %%
plt.plot(rewards)
plt.title("Cumulative Reward vs Episode")
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.grid(True)
plt.show()

# %%
model=model.load('ppo_lunarlander.zip')

env = gym.make("LunarLander-v3",render_mode="human")

obs,info = env.reset()
done = False

obs,info = env.reset()
for _ in range(500):
    action, _ = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    env.render()

    if done:
        obs,info = env.reset()

env.close()
